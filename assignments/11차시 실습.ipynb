# %% [markdown]
# ## CNN을 이용한 흑백 이미지 분류

# %% [markdown]
# # Step 1. Task 설정
# 분석할 데이터 :  Fashion MNIST
# - 라벨 있음 -> 지도학습
# - 라벨종류 -> discrete variable -> 분류분석
# - 라벨 수 : 10 -> 다중분류

# %%
# 필요한 모듈 불러오기
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
from tensorflow.keras.layers import Input, Conv2D, Dense, Flatten, Dropout
from tensorflow.keras.models import Model

# %% [markdown]
# # STEP 2. 데이터셋 준비하기

# %% [markdown]
# ## 데이터셋 살펴보기 : Fashion MNIST 데이터셋
# * Fashion MNIST는 운동화, 셔츠, 샌들, 가방, 구두 등 패션이미지 들을 모아둔 데이터셋
# * 이미지: 각 28*28픽셀, grayscale 이미지임 (색상이 없는 2D 이미지)
# * 샘플수 : 총 70,000 (훈련셋 60,000, 테스트셋 10,000)
# * 총 10가지의 class가 있음(클래스별 7천개)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
fashion_mnist = tf.keras.datasets.fashion_mnist

# %%
 (x_train, y_train) , (x_test, y_test) = fashion_mnist.load_data()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-labels-idx1-ubyte.gz
# 29515/29515 [==============================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-images-idx3-ubyte.gz
# 26421880/26421880 [==============================] - 2s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-labels-idx1-ubyte.gz
# 5148/5148 [==============================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-images-idx3-ubyte.gz
# 4422102/4422102 [==============================] - 1s 0us/step

# %% [markdown]
# ### 데이터 전처리.
# 정규화.
#
# 이미지 데이터 ( 0 ~ 255 ) 값을 가짐.
#
# - 픽셀 내 색상값을 255로 나누어 준다. : 0~1 값을 가지게 된다.

# %%
x_train, x_test = x_train / 255.0, x_test / 255.0

# %%
print("x_train. shape: ",x_train.shape )
# Out:
# x_train. shape:  (60000, 28, 28)

# %% [markdown]
# ### 컨볼루션 함수
#  - 기본적으로 3D 데이터를 받아온다.
#  - 회색조 이미지(2D)를 처리하기 위해서 차원 확장을 해준다.

# %%
x_train = np.expand_dims(x_train, -1)
x_test= np.expand_dims(x_test, -1)
print(x_train.shape)
# Out:
# (60000, 28, 28, 1)

# %%
# 라벨 수 확인
K = len(set(y_train))
print(K)
# Out:
# 10

# %%
print(y_train)
# sparse category 형식이다.
# Out:
# [9 0 0 ... 3 0 5]

# %% [markdown]
# ## Step 3. 모델 훈련하기.

# %% [markdown]
# ## CNN의 구조
# ![image.png](data:image/png;base64,...)

# %%
x_train[0].shape
# Out:
# (28, 28, 1)

# %%
# Stage 1. Convolution <- feature 추출
# 입력 레이어의 크기 설정
i = Input(shape = x_train[0].shape)

x = Conv2D(32, (3,3), strides = 2, activation = 'relu' )(i)

x = Conv2D(64, (3,3), strides = 2, activation = 'relu' )(x)

x = Conv2D(128, (3,3), strides = 2, activation = 'relu' )(x)

# %%
x = Flatten()(x)

# %%
x = Dropout(0.2)(x)

# %%
# Stage 2 : ANN
x = Dense(512, activation = 'relu')(x)

# Output
x = Dense(K, activation = 'softmax')(x)


model = Model(i,x)

# %%
model.compile(optimizer='adam',
              loss = 'sparse_categorical_crossentropy',
              metrics = ['accuracy']
              )

# %%
r = model.fit(x_train,y_train, validation_data=(x_test, y_test) , epochs= 15)
# Out:
# Epoch 1/15
# 1875/1875 [==============================] - 18s 4ms/step - loss: 0.5185 - accuracy: 0.8066 - val_loss: 0.4189 - val_accuracy: 0.8454
# Epoch 2/15
# 1875/1875 [==============================] - 7s 3ms/step - loss: 0.3627 - accuracy: 0.8634 - val_loss: 0.3453 - val_accuracy: 0.8725
# Epoch 3/15
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.3089 - accuracy: 0.8828 - val_loss: 0.3364 - val_accuracy: 0.8794
# Epoch 4/15
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.2768 - accuracy: 0.8951 - val_loss: 0.3212 - val_accuracy: 0.8863
# Epoch 5/15
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.2483 - accuracy: 0.9055 - val_loss: 0.2913 - val_accuracy: 0.8947
# Epoch 6/15
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.2236 - accuracy: 0.9155 - val_loss: 0.2965 - val_accuracy: 0.8936
# Epoch 7/15
# 1875/1875 [==============================] - 7s 3ms/step - loss: 0.2046 - accuracy: 0.9220 - val_loss: 0.3053 - val_accuracy: 0.8926
# Epoch 8/15
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.1891 - accuracy: 0.9277 - val_loss: 0.3126 - val_accuracy: 0.8930
# Epoch 9/15
# 1875/1875 [==============================] - 7s 3ms/step - loss: 0.1726 - accuracy: 0.9337 - val_loss: 0.2983 - val_accuracy: 0.9011
# Epoch 10/15
# 1875/1875 [==============================] - 7s 3ms/step - loss: 0.1573 - accuracy: 0.9399 - val_loss: 0.3152 - val_accuracy: 0.8962
# Epoch 11/15
# 1875/1875 [==============================] - 7s 3ms/step - loss: 0.1468 - accuracy: 0.9436 - val_loss: 0.3199 - val_accuracy: 0.9026
# Epoch 12/15
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.1354 - accuracy: 0.9487 - val_loss: 0.3350 - val_accuracy: 0.9019
# Epoch 13/15
# 1875/1875 [==============================] - 7s 3ms/step - loss: 0.1277 - accuracy: 0.9513 - val_loss: 0.3633 - val_accuracy: 0.9000
# Epoch 14/15
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.1191 - accuracy: 0.9541 - val_loss: 0.3528 - val_accuracy: 0.9023
# Epoch 15/15
# 1875/1875 [==============================] - 7s 3ms/step - loss: 0.1119 - accuracy: 0.9568 - val_loss: 0.3652 - val_accuracy: 0.8983

# %% [markdown]
# # Step 4. 결과물 평가
#
# # Step 4. 모델 평가
# 모델학습의 결과로 나오는 학습데이터의 손실값과 테스트 데이터의 손실값을 비교하여 적절한 학습이 진행되는지 확인해 본다
# ![image.png](data:image/png;base64,...)

# %%
plt.plot(r.history['loss'] , label='loss')
plt.plot(r.history['val_loss'] , label='val_loss')
plt.legend()
plt.show()

# %%
plt.plot(r.history['accuracy'] , label='accuracy')
plt.plot(r.history['val_accuracy'] , label='val_accuracy')
plt.legend()
plt.show()

# %%
# 오차행렬 시각화 하기
from sklearn.metrics import confusion_matrix
import itertools
# 데이터 구조를 하나하나 훑어보기 위한 모듈

# 오차행렬을 출력하고 시각화 까지 해 주는 사용자 정의 함수를 설정한다
# 단순히 갯수로 출력하는 것이 아니라 % 로 출력하고 싶다면 normalize=True 로 바꾸어 준다
def plot_confusion_matrix(cm, classes,
                          normalize=False,
                          title='Confusion matrix',
                          cmap=plt.cm.Blues):

  if normalize:
      cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
      print("Normalized confusion matrix")
  else:
      print('Confusion matrix, without normalization')

  print(cm)

  plt.imshow(cm, interpolation='nearest', cmap=cmap)
  plt.title(title)
  plt.colorbar()
  tick_marks = np.arange(len(classes))
  plt.xticks(tick_marks, classes, rotation=45)
  plt.yticks(tick_marks, classes)

  fmt = '.2f' if normalize else 'd'
  thresh = cm.max() / 2.
  for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
      plt.text(j, i, format(cm[i, j], fmt),
               horizontalalignment="center",
               color="white" if cm[i, j] > thresh else "black")

  plt.tight_layout()
  plt.ylabel('True label')
  plt.xlabel('Predicted label')
  plt.show()


p_test = model.predict(x_test).argmax(axis=1)
cm = confusion_matrix(y_test, p_test)
plot_confusion_matrix(cm, list(range(10)))
# Out:
# 313/313 [==============================] - 1s 1ms/step
# Confusion matrix, without normalization
# [[868   1  20  15   5   1  82   1   7   0]
#  [  1 978   1  14   2   0   2   0   2   0]
#  [ 18   0 866   7  53   0  54   0   2   0]
#  [ 19   3  15 917  29   0  14   0   1   2]
#  [  2   1  67  24 823   0  82   0   1   0]
#  [  0   0   0   0   0 970   1  20   0   9]
#  [136   2  77  26  86   0 662   0  11   0]
#  [  0   0   0   0   0   4   0 957   0  39]
#  [  1   2   4   1   4   3   9   3 973   0]
#  [  1   0   0   0   0   4   0  24   2 969]]

# %%
labels = '''T-shirt/top
Trouser
Pullover
Dress
Coat
Sandal
Shirt
Sneaker
Bag
Ankle boot'''.split("\n")

# %%
misclassified_idx = np.where(p_test != y_test)[0]
i = np.random.choice(misclassified_idx)
plt.imshow(x_test[i].reshape(28,28), cmap='gray')
plt.title("True label: %s Predicted: %s" % (labels[y_test[i]], labels[p_test[i]]));
